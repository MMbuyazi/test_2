# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Print the count of duplicated rows in the DataFrame
print(df.duplicated().sum())

# %%
# Generate random data representing daily temperatures over one year
data = np.random.normal(loc=20.0, scale=5.0, size=365)

# Create a histogram of the data with specified bins, color, and transparency
plt.hist(data, bins=20, color='blue', alpha=0.7)

# Set the title of the plot
plt.title('Histogram of Country_name per Country ISO3 ')

# Set the label for the x-axis
plt.xlabel('Country_name')

# Set the label for the y-axis
plt.ylabel('Country ISO3')

# Display grid lines on the plot
plt.grid(True)

# Show the plot
plt.show()

# %%
Country_Name = ['South Africa', 'South Africa', 'South Africa', 'South Africa']
Years= [2017, 2015, 2008, 2013]
# Creating pie chart
plt.figure(figsize=(7, 7))
plt.pie(Years, labels=Country_Name, autopct='%1.1f%%', startangle=140)
plt.title('Pie Char For Year share')
plt.show()

# %%
Years= [2017,2012, 2008, 2013]
Country_Name = ['South Africa', 'South Africa', 'South Africa', 'South Africa']
plt.scatter(Year, Country_Name)
plt.title('Scatter Plot of Years vs. Country_Name')
plt.xlabel('Years')
plt.ylabel('Country_Name')
plt.show()

# %%
years = [2019, 2015, 2012, 2010,2016,2010]

# Convert the list of years to numpy array
years_array = np.array(years)

# Calculate summary statistics
mean = np.mean(years_array)
median = np.median(years_array)
std_dev = np.std(years_array)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 2013.6666666666667
# Median: 2013.5
# Standard Deviation: 3.2998316455372216
